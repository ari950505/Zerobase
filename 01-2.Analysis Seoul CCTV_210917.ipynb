# %% [markdown]
# # 01-2. Analysis Seoul CCTV

# %% [markdown]
# ## 2. CCTV 데이터 훑어보기

# %%
import pandas as pd
import numpy as np

# %%
CCTV_Seoul = pd.read_csv('../../data/01.Seoul_CCTV.csv', encoding ='utf-8')
CCTV_Seoul.head()
# Out:
#     구분      총계 2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0    계  77,032    7,667  2,200  3,491  4,439  6,582  8,129  9,947  9,876
# 1  종로구   1,772      813      0      0    210    150      1    261     85
# 2  중 구   2,333       16    114     87     77    236    240    372    386
# 3  용산구   2,383       34     71    234    125    221    298    351    125
# 4  성동구   3,602      448    125    212    105    339    310    874    390
#
#     2019년   2020년  2021년
# 0  11,961  11,132  1,608
# 1       9     200     43
# 2     155     361    289
# 3     307     617      0
# 4     262     461     76

# %%
CCTV_Seoul.tail()
# Out:
#      구분     총계 2012년 이전 2012년 2013년 2014년 2015년 2016년 2017년 2018년 2019년 2020년  \
# 21  관악구  4,942      428   205   291   513   529   621   687   663   640   331
# 22  서초구  3,704      116    75    94    71   563   516  1060   428   358   420
# 23  강남구  6,502      124    77    75   597   840  1310   999   748   789   942
# 24  송파구  2,854       72    61    86    85   215   148   241   542  1068   235
# 25  강동구  2,547      332    27   163    49   154   202   273   377   356   614
#
#    2021년
# 21    34
# 22     3
# 23     1
# 24   101
# 25     0

# %%
CCTV_Seoul.rename(columns = {CCTV_Seoul.columns[0] : '구별'})
# Out:
#       구별      총계 2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0      계  77,032    7,667  2,200  3,491  4,439  6,582  8,129  9,947  9,876
# 1    종로구   1,772      813      0      0    210    150      1    261     85
# 2    중 구   2,333       16    114     87     77    236    240    372    386
# 3    용산구   2,383       34     71    234    125    221    298    351    125
# 4    성동구   3,602      448    125    212    105    339    310    874    390
# 5    광진구   2,588       35     57    100    187     98     52    675    465
# 6   동대문구   2,497    1,090    146     60     29    111    233    136    197
# 7    중랑구   3,296      302     24    253     88    141    161    162    173
# 8    성북구   3,958       83     78    170    230    323    594    460    867
# 9    강북구   2,462        0      0     24     65    105    243      6    392
# 10   도봉구   1,629       39     22     96    181     79    159    134    222
# ...

# %%
CCTV_Seoul.sort_values(by = '총계',ascending=True).head(5)
# Out:
#      구분     총계 2012년 이전 2012년 2013년 2014년 2015년 2016년 2017년 2018년 2019년 2020년  \
# 10  도봉구  1,629       39    22    96   181    79   159   134   222   198   168
# 1   종로구  1,772      813     0     0   210   150     1   261    85     9   200
# 20  동작구  2,297       41    24    25   503   128   253   271   300   322   419
# 2   중 구  2,333       16   114    87    77   236   240   372   386   155   361
# 18  금천구  2,374        0     0   178    80   361   133   196   540   369   508
#
#    2021년
# 10   331
# 1     43
# 20    11
# 2    289
# 18     9

# %%
CCTV_Seoul.sort_values(by = '총계',ascending= False).head(5)
# Out:
#      구분      총계 2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0     계  77,032    7,667  2,200  3,491  4,439  6,582  8,129  9,947  9,876
# 23  강남구   6,502      124     77     75    597    840   1310    999    748
# 21  관악구   4,942      428    205    291    513    529    621    687    663
# 17  구로구   4,075      852    216    349    187    268    326    540    488
# 8   성북구   3,958       83     78    170    230    323    594    460    867
#
#      2019년   2020년  2021년
# 0   11,961  11,132  1,608
# 23     789     942      1
# 21     640     331     34
# 17     434     415      0
# 8      714     251    188

# %%
# 기존 컬럼이 없으면 추가, 있으면 수정
CCTV_Seoul['최근증가율'] = {
    (CCTV_Seoul['2016냔'] + CCTV_Seoul['2015년'] + CCTV_Seoul['2014년']) / CCTV_Seoul['2012년 이전'] *100

}

CCTV_Seoul.sort_values(by = ' 최근증가율'), ascending =False.head()
# Out:
#   File "<ipython-input-17-30afec96b439>", line 7
#     CCTV_Seoul.sort_values(by = ' 최근증가율'), ascending =False.head()
#     ^
# SyntaxError: cannot assign to function call
